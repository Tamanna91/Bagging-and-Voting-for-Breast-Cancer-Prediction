# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_set= pd.read_csv('/content/drive/My Drive/Dataset/Breast_Cancer_new.csv')
#data_set[np.isnan(data_set) == True] = 1.0
data_set
# Out:
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302        17.99         10.38          122.80     1001.0
# 1      842517        20.57         17.77          132.90     1326.0
# 2    84300903        19.69         21.25          130.00     1203.0
# 3    84348301        11.42         20.38           77.58      386.1
# 4    84358402        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564    926424        21.56         22.39          142.00     1479.0
# 565    926682        20.13         28.25          131.20     1261.0
# 566    926954        16.60         28.08          108.30      858.1
# 567    927241        20.60         29.33          140.10     1265.0
# 568     92751         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
data_set.isnull().sum()
# Out:
# id                         0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# diagnosis                  0
# ...

# %%
y = data_set["diagnosis"]

sns.countplot(y)


target_temp = data_set.diagnosis.value_counts()

print(target_temp)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
data_set.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
data_set["diagnosis"] = data_set["diagnosis"].apply(lambda val : 1 if val == 'M' else 0 if val == 'B' else val)

# %%
data_set.drop(["id","texture_worst","concavity_se","texture_se","concave points_se","concave points_se","concave points_se","symmetry_se","smoothness_se","texture_mean","smoothness_worst","symmetry_mean","smoothness_mean","symmetry_worst","compactness_se","fractal_dimension_se","fractal_dimension_mean"], axis = 1, inplace = True)
data_set
# Out:
#      radius_mean  perimeter_mean  area_mean  compactness_mean  concavity_mean  \
# 0          17.99          122.80     1001.0           0.27760         0.30010
# 1          20.57          132.90     1326.0           0.07864         0.08690
# 2          19.69          130.00     1203.0           0.15990         0.19740
# 3          11.42           77.58      386.1           0.28390         0.24140
# 4          20.29          135.10     1297.0           0.13280         0.19800
# ..           ...             ...        ...               ...             ...
# 564        21.56          142.00     1479.0           0.11590         0.24390
# 565        20.13          131.20     1261.0           0.10340         0.14400
# 566        16.60          108.30      858.1           0.10230         0.09251
# 567        20.60          140.10     1265.0           0.27700         0.35140
# 568         7.76           47.92      181.0           0.04362         0.00000
#
# ...

# %%
x= data_set.iloc[:, 0:15].values
y= data_set.iloc[:, 16].values

# %%
data_set.plot.area()

# %%
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.20, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
from sklearn.feature_selection import mutual_info_classif, mutual_info_regression
mi = mutual_info_classif(x_train, y_train)
mi_f = pd.Series(mi)
#print(mi_f)
#df = pd.DataFrame(x_train)
#mi_f.index = df.columns
#dfcolumns=pd.DataFrame(data_set.columns)
dfcolumns=pd.DataFrame(data_set.columns)
#print(dfcolumns.sort_index())
features_rank1=pd.concat([dfcolumns,mi_f], axis=1)
#print(features_rank1)
score= mi_f.sort_values(ascending=False)
#print(score)
features_rank=pd.concat([dfcolumns,mi_f.sort_values(ascending=False)], axis=1)
features_rank.columns=['Features','Score']
features_rank
#features_rank=pd.concat([dfcolumns,score(ascending=False)], axis=1)
print(features_rank)
features_rank.plot(kind='barh', color='red')
plt.show()
# Out:
#                    Features     Score
# 0               radius_mean  0.341923
# 1            perimeter_mean  0.407932
# 2                 area_mean  0.356326
# 3          compactness_mean  0.244767
# 4            concavity_mean  0.373713
# 5       concave points_mean  0.449160
# 6                 radius_se  0.245269
# 7              perimeter_se  0.239734
# 8                   area_se  0.339798
# 9              radius_worst  0.435189
# 10          perimeter_worst  0.462195
# 11               area_worst  0.449955
# 12        compactness_worst  0.222790
# 13          concavity_worst  0.303004
# 14     concave points_worst  0.434031
# 15  fractal_dimension_worst       NaN
# 16                diagnosis       NaN

# %%
features_rank.nlargest(15,'Score')
# Out:
#                 Features     Score
# 10       perimeter_worst  0.462195
# 11            area_worst  0.449955
# 5    concave points_mean  0.449160
# 9           radius_worst  0.435189
# 14  concave points_worst  0.434031
# 1         perimeter_mean  0.407932
# 4         concavity_mean  0.373713
# 2              area_mean  0.356326
# 0            radius_mean  0.341923
# 8                area_se  0.339798
# 13       concavity_worst  0.303004
# 6              radius_se  0.245269
# 3       compactness_mean  0.244767
# 7           perimeter_se  0.239734
# 12     compactness_worst  0.222790

# %%
y = data_set["diagnosis"]
sns.countplot(y)
target_temp = data_set.diagnosis.value_counts()
print(target_temp)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# 0    357
# 1    212
# Name: diagnosis, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import classification_report 
from sklearn.metrics import confusion_matrix
#classifier= LogisticRegression(random_state=50)  
classifier= LogisticRegression() 
print(classifier)
classifier.fit(x_train, y_train)  
y_pred= classifier.predict(x_test)
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
print(cnf_matrix) 
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import cross_val_score

#print('preciision:', accuracies.precision_score()*100,'%')
recall = cross_val_score(classifier, x, y,cv=5, scoring='recall')
precision = cross_val_score(classifier, x, y,cv=5, scoring='precision')
accuracy = cross_val_score(classifier, x, y,cv=5, scoring='accuracy')
f1_score = cross_val_score(classifier, x, y,cv=5, scoring='f1_macro')
#print('recall:', recall)
print('Recal_final:', recall.mean()*100,'%')
#print('precision:', precision)
print('precision_final:', precision.mean()*100,'%')
#print('f1_score:', f1_score)
print('accuracy_final:', accuracy.mean()*100,'%')
print('f1_score_final:', f1_score.mean()*100,'%')

from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
y_score1 = classifier.predict_proba(x_test)[:,1]
false_positive_rate1, true_positive_rate1, threshold1 = roc_curve(y_test, y_score1)
print('roc_auc_score for Logistic Regression: ', roc_auc_score(y_test, y_score1))


plt.subplots(1, figsize=(5,5))
plt.title('Receiver Operating Characteristic - Logistic regression')
plt.plot(false_positive_rate1, true_positive_rate1)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# LogisticRegression()
# [[62  5]
#  [ 2 45]]
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.ensemble import RandomForestClassifier  
classifier= RandomForestClassifier(n_estimators= 10, criterion="entropy")  
print(classifier)
classifier.fit(x_train, y_train)  
y_pred= classifier.predict(x_test)
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
print(cnf_matrix) 
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import cross_val_score

#print('preciision:', accuracies.precision_score()*100,'%')
recall = cross_val_score(classifier, x, y,cv=5, scoring='recall')
precision = cross_val_score(classifier, x, y,cv=5, scoring='precision')
accuracy = cross_val_score(classifier, x, y,cv=5, scoring='accuracy')
f1_score = cross_val_score(classifier, x, y,cv=5, scoring='f1_macro')
#print('recall:', recall)
print('Recal_final:', recall.mean()*100,'%')
#print('precision:', precision)
print('precision_final:', precision.mean()*100,'%')
#print('f1_score:', f1_score)
print('accuracy_final:', accuracy.mean()*100,'%')
print('f1_score_final:', f1_score.mean()*100,'%')
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
y_score1 = classifier.predict_proba(x_test)[:,1]
false_positive_rate1, true_positive_rate1, threshold1 = roc_curve(y_test, y_score1)
print('roc_auc_score for RF: ', roc_auc_score(y_test, y_score1))
plt.subplots(1, figsize=(5,5))
plt.title('Receiver Operating Characteristic - Logistic regression')
plt.plot(false_positive_rate1, true_positive_rate1)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)
# [[64  3]
#  [ 3 44]]
# Recal_final: 90.58693244739754 %
# precision_final: 94.03802141011444 %
# accuracy_final: 94.20121099208197 %
# f1_score_final: 94.67715519982957 %
# roc_auc_score for RF:  0.9923785328675769

# %%
from sklearn.neighbors import KNeighborsClassifier  
classifier= KNeighborsClassifier(n_neighbors=20, metric='minkowski', p=10 )  
classifier.fit(x_train, y_train)  
y_pred= classifier.predict(x_test)
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
print(cnf_matrix) 
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import cross_val_score

#print('preciision:', accuracies.precision_score()*100,'%')
recall = cross_val_score(classifier, x, y,cv=5, scoring='recall')
precision = cross_val_score(classifier, x, y,cv=5, scoring='precision')
accuracy = cross_val_score(classifier, x, y,cv=5, scoring='accuracy')
f1_score = cross_val_score(classifier, x, y,cv=5, scoring='f1_macro')
#print('recall:', recall)
print('Recal_final:', recall.mean()*100,'%')
#print('precision:', precision)
print('precision_final:', precision.mean()*100,'%')
#print('f1_score:', f1_score)
print('accuracy_final:', accuracy.mean()*100,'%')
print('f1_score_final:', f1_score.mean()*100,'%')
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
y_score1 = classifier.predict_proba(x_test)[:,1]
false_positive_rate1, true_positive_rate1, threshold1 = roc_curve(y_test, y_score1)
print('roc_auc_score for KNN: ', roc_auc_score(y_test, y_score1))
plt.subplots(1, figsize=(5,5))
plt.title('Receiver Operating Characteristic - Logistic regression')
plt.plot(false_positive_rate1, true_positive_rate1)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# [[66  1]
#  [ 3 44]]
# Recal_final: 84.98338870431894 %
# precision_final: 94.73931466850429 %
# accuracy_final: 92.62226362366093 %
# f1_score_final: 91.83538907990017 %
# roc_auc_score for KNN:  0.9761829152111781

# %%
from sklearn.naive_bayes import GaussianNB  
classifier = GaussianNB()  
classifier.fit(x_train,y_train)  
y_pred= classifier.predict(x_test)
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
print(cnf_matrix) 
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import cross_val_score

#print('preciision:', accuracies.precision_score()*100,'%')
recall = cross_val_score(classifier, x, y,cv=5, scoring='recall')
precision = cross_val_score(classifier, x, y,cv=5, scoring='precision')
accuracy = cross_val_score(classifier, x, y,cv=5, scoring='accuracy')
f1_score = cross_val_score(classifier, x, y,cv=5, scoring='f1_macro')
#print('recall:', recall)
print('Recal_final:', recall.mean()*100,'%')
#print('precision:', precision)
print('precision_final:', precision.mean()*100,'%')
#print('f1_score:', f1_score)
print('accuracy_final:', accuracy.mean()*100,'%')
print('f1_score_final:', f1_score.mean()*100,'%')
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
y_score1 = classifier.predict_proba(x_test)[:,1]
false_positive_rate1, true_positive_rate1, threshold1 = roc_curve(y_test, y_score1)
print('roc_auc_score for NB: ', roc_auc_score(y_test, y_score1))
plt.subplots(1, figsize=(5,5))
plt.title('Receiver Operating Characteristic - Logistic regression')
plt.plot(false_positive_rate1, true_positive_rate1)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# [[62  5]
#  [ 4 43]]
# Recal_final: 86.843853820598 %
# precision_final: 92.99565204443255 %
# accuracy_final: 92.62226362366093 %
# f1_score_final: 91.9875599874563 %
# roc_auc_score for NB:  0.9863448713877422

# %%
from sklearn.svm import SVC # "Support vector classifier"  
classifier = SVC(kernel='rbf', random_state=0,probability=True)  
classifier.fit(x_train, y_train) 
y_pred= classifier.predict(x_test)
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix 
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import cross_val_score

#print('preciision:', accuracies.precision_score()*100,'%')
recall = cross_val_score(classifier, x, y,cv=5, scoring='recall')
precision = cross_val_score(classifier, x, y,cv=5, scoring='precision')
accuracy = cross_val_score(classifier, x, y,cv=5, scoring='accuracy')
f1_score = cross_val_score(classifier, x, y,cv=5, scoring='f1_macro')
#print('Precision: %.5f' % model.precision_score(y_test, y_pred))


from sklearn import metrics
print('Accuracy: %.3f' % metrics.accuracy_score(y_test, y_pred))
print('Precision: %.5f' % metrics.precision_score(y_test, y_pred))
print('Recall: %.5f' % metrics.recall_score(y_test, y_pred))
print('F1 Score: %.5f' % metrics.f1_score(y_test, y_pred))

from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
y_score1 = classifier.predict_proba(x_test)[:,1]
false_positive_rate1, true_positive_rate1, threshold1 = roc_curve(y_test, y_score1)
print('roc_auc_score for SVC: ', roc_auc_score(y_test, y_score1))

plt.subplots(1, figsize=(5,5))
plt.title('Receiver Operating Characteristic - Logistic regression')
plt.plot(false_positive_rate1, true_positive_rate1)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# Accuracy: 0.930
# Precision: 0.97561
# Recall: 0.85106
# F1 Score: 0.90909
# roc_auc_score for SVC:  0.9844395046046364

# %%
from sklearn.tree import DecisionTreeClassifier
classifier= DecisionTreeClassifier(criterion='entropy', random_state=0)  
classifier.fit(x_train, y_train) 
y_pred= classifier.predict(x_test)
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
#print(cnf_matrix) 
sns.heatmap(cnf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=['healthy', 'sick'], yticklabels=['healthy', 'sick'])
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Decision Tree: Confusion Matrix')
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import cross_val_score

from sklearn import metrics
print('Accuracy: %.3f' % metrics.accuracy_score(y_test, y_pred))
print('Precision: %.5f' % metrics.precision_score(y_test, y_pred))
print('Recall: %.5f' % metrics.recall_score(y_test, y_pred))
print('F1 Score: %.5f' % metrics.f1_score(y_test, y_pred))
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
y_score1 = classifier.predict_proba(x_test)[:,1]
false_positive_rate1, true_positive_rate1, threshold1 = roc_curve(y_test, y_score1)
print('roc_auc_score for DT: ', roc_auc_score(y_test, y_score1))

plt.subplots(1, figsize=(5,5))
plt.title('Receiver Operating Characteristic - Logistic regression')
plt.plot(false_positive_rate1, true_positive_rate1)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# Accuracy: 0.921
# Precision: 0.93182
# Recall: 0.87234
# F1 Score: 0.90110
# roc_auc_score for DT:  0.913782153064465

# %%
from sklearn.ensemble import RandomForestClassifier  
classifier = RandomForestClassifier(n_estimators=20)
classifier.fit(x_train, y_train) 
plt.subplots(figsize=(10,5))

conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=['healthy', 'sick'], yticklabels=['healthy', 'sick'])
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Random Forest: Confusion Matrix')

from sklearn import metrics
print('Accuracy: %.3f' % metrics.accuracy_score(y_test, y_pred))
print('Precision: %.5f' % metrics.precision_score(y_test, y_pred))
print('Recall: %.5f' % metrics.recall_score(y_test, y_pred))
print('F1 Score: %.5f' % metrics.f1_score(y_test, y_pred))

from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
y_score1 = classifier.predict_proba(x_test)[:,1]
false_positive_rate1, true_positive_rate1, threshold1 = roc_curve(y_test, y_score1)
print('roc_auc_score for DT: ', roc_auc_score(y_test, y_score1))

plt.subplots(1, figsize=(5,5))
plt.title('Receiver Operating Characteristic - Logistic regression')
plt.plot(false_positive_rate1, true_positive_rate1)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# Accuracy: 0.921
# Precision: 0.93182
# Recall: 0.87234
# F1 Score: 0.90110
# roc_auc_score for DT:  0.9915846300412829

# %% [markdown]
# HARD VOTIING

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
log_clf = LogisticRegression(solver="lbfgs", random_state=42)
rnd_clf = RandomForestClassifier(n_estimators=100, random_state=42)
svm_clf = SVC(gamma="scale", random_state=42)
voting_clf = VotingClassifier(
 estimators=[('lr', log_clf), ('rf', rnd_clf), ('svc', svm_clf)],
 voting='hard')

voting_clf.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# VotingClassifier(estimators=[('lr', LogisticRegression(random_state=42)),
#                              ('rf', RandomForestClassifier(random_state=42)),
#                              ('svc', SVC(random_state=42))])

# %%
from sklearn.metrics import accuracy_score
for clf in (log_clf, rnd_clf, svm_clf, voting_clf):
 clf.fit(x_train, y_train)
 y_pred = clf.predict(x_test)
 print(clf.__class__.__name__, accuracy_score(y_test, y_pred))
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression 0.9385964912280702
# RandomForestClassifier 0.9385964912280702
# SVC 0.9298245614035088
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %% [markdown]
# SOFT VOTING

# %%
log_clf = LogisticRegression(solver="lbfgs", random_state=42)
rnd_clf = RandomForestClassifier(n_estimators=100, random_state=42)
svm_clf = SVC(gamma="scale", probability=True, random_state=42)
voting_clf = VotingClassifier(
 estimators=[('lr', log_clf), ('rf', rnd_clf), ('svc', svm_clf)],
 voting='soft')
voting_clf.fit(x_train, y_train)

from sklearn.metrics import accuracy_score
for clf in (log_clf, rnd_clf, svm_clf, voting_clf):
 clf.fit(x_train, y_train)
 y_pred = clf.predict(x_test)
 print(clf.__class__.__name__, accuracy_score(y_test, y_pred))

from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
y_score2 = clf.predict_proba(x_test)[:,1]
false_positive_rate1, true_positive_rate1, threshold1 = roc_curve(y_test, y_score1)
print('roc_auc_score for DT: ', roc_auc_score(y_test, y_score2))

plt.subplots(1, figsize=(5,5))
plt.title('Receiver Operating Characteristic - Logistic regression')
plt.plot(false_positive_rate1, true_positive_rate1)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7"), plt.plot([1, 1] , c=".7")
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# Bagging ensembles

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
bag_clf = BaggingClassifier(
 DecisionTreeClassifier(random_state=20), n_estimators=100,max_samples=10, bootstrap=True, random_state=20)
bag_clf.fit(x_train, y_train)
y_pred = bag_clf.predict(x_test)

from sklearn.metrics import accuracy_score
print('Accuracy: ',accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.9385964912280702
